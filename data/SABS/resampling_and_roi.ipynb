# %% [markdown]
# ## MICCAI 2015 Abdominal dataset
#
# ### Overview
#
# This is the second step of preprocessing
#
# Cut out irrelevant empty boundary and resample to 256-by-256 in axial plane.
#
# Input: intensity-normalized images
#
# Output: spacially resampled images

# %%
# !python -m pip install SimpleITK
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting SimpleITK
#   Downloading SimpleITK-2.1.1.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (48.4 MB)
#      |████████████████████████████████| 48.4 MB 2.1 MB/s
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.1.1.2

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %reset
# %load_ext autoreload
# %autoreload 2
import numpy as np
import os
import glob
import SimpleITK as sitk
import sys

os.chdir("/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation")
py_file_location = '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/dataloaders'
# sys.path.insert(0, '../../dataloaders/')
sys.path.append(os.path.abspath(py_file_location))
import niftiio as nio
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
IMG_FOLDER = "/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/"
SEG_FOLDER = IMG_FOLDER
imgs = glob.glob(IMG_FOLDER + "/image_*.nii.gz")
imgs = [ fid for fid in sorted(imgs) ]
segs = [ fid for fid in sorted(glob.glob(SEG_FOLDER + "/label_*.nii.gz")) ]

pids = [pid.split("_")[-1].split(".")[0] for pid in imgs]

# %%
# helper functions copy pasted
def resample_by_res(mov_img_obj, new_spacing, interpolator = sitk.sitkLinear, logging = True):
    resample = sitk.ResampleImageFilter()
    resample.SetInterpolator(interpolator)
    resample.SetOutputDirection(mov_img_obj.GetDirection())
    resample.SetOutputOrigin(mov_img_obj.GetOrigin())
    mov_spacing = mov_img_obj.GetSpacing()

    resample.SetOutputSpacing(new_spacing)
    RES_COE = np.array(mov_spacing) * 1.0 / np.array(new_spacing)
    new_size = np.array(mov_img_obj.GetSize()) *  RES_COE 

    resample.SetSize( [int(sz+1) for sz in new_size] )
    if logging:
        print("Spacing: {} -> {}".format(mov_spacing, new_spacing))
        print("Size {} -> {}".format( mov_img_obj.GetSize(), new_size ))

    return resample.Execute(mov_img_obj)

def resample_lb_by_res(mov_lb_obj, new_spacing, interpolator = sitk.sitkLinear, ref_img = None, logging = True):
    src_mat = sitk.GetArrayFromImage(mov_lb_obj)
    lbvs = np.unique(src_mat)
    if logging:
        print("Label values: {}".format(lbvs))
    for idx, lbv in enumerate(lbvs):
        _src_curr_mat = np.float32(src_mat == lbv) 
        _src_curr_obj = sitk.GetImageFromArray(_src_curr_mat)
        _src_curr_obj.CopyInformation(mov_lb_obj)
        _tar_curr_obj = resample_by_res( _src_curr_obj, new_spacing, interpolator, logging )
        _tar_curr_mat = np.rint(sitk.GetArrayFromImage(_tar_curr_obj)) * lbv
        if idx == 0:
            out_vol = _tar_curr_mat
        else:
            out_vol[_tar_curr_mat == lbv] = lbv
    out_obj = sitk.GetImageFromArray(out_vol)
    out_obj.SetSpacing( _tar_curr_obj.GetSpacing() )
    if ref_img != None:
        out_obj.CopyInformation(ref_img)
    return out_obj
        
## Then crop ROI
def get_label_center(label):
    nnz = np.sum(label > 1e-5)
    return np.int32(np.rint(np.sum(np.nonzero(label), axis = 1) * 1.0 / nnz))

def image_crop(ori_vol, crop_size, referece_ctr_idx, padval = 0., only_2d = True):
    """ crop a 3d matrix given the index of the new volume on the original volume
        Args:
            refernce_ctr_idx: the center of the new volume on the original volume (in indices)
            only_2d: only do cropping on first two dimensions
    """
    _expand_cropsize = [x + 1 for x in crop_size] # to deal with boundary case
    if only_2d:
        assert len(crop_size) == 2, "Actual len {}".format(len(crop_size))
        assert len(referece_ctr_idx) == 2, "Actual len {}".format(len(referece_ctr_idx))
        _expand_cropsize.append(ori_vol.shape[-1])
        
    image_patch = np.ones(tuple(_expand_cropsize)) * padval

    half_size = tuple( [int(x * 1.0 / 2) for x in _expand_cropsize] )
    _min_idx = [0,0,0]
    _max_idx = list(ori_vol.shape)

    # bias of actual cropped size to the beginning and the end of this volume
    _bias_start = [0,0,0]
    _bias_end = [0,0,0]

    for dim,hsize in enumerate(half_size):
        if dim == 2 and only_2d:
            break

        _bias_start[dim] = np.min([hsize, referece_ctr_idx[dim]])
        _bias_end[dim] = np.min([hsize, ori_vol.shape[dim] - referece_ctr_idx[dim]])

        _min_idx[dim] = referece_ctr_idx[dim] - _bias_start[dim]
        _max_idx[dim] = referece_ctr_idx[dim] + _bias_end[dim]
        
    if only_2d:
        image_patch[ half_size[0] - _bias_start[0]: half_size[0] +_bias_end[0], \
                half_size[1] - _bias_start[1]: half_size[1] +_bias_end[1], ... ] = \
                ori_vol[ referece_ctr_idx[0] - _bias_start[0]: referece_ctr_idx[0] +_bias_end[0], \
                referece_ctr_idx[1] - _bias_start[1]: referece_ctr_idx[1] +_bias_end[1], ... ]

        image_patch = image_patch[ 0: crop_size[0], 0: crop_size[1], : ]
    # then goes back to original volume
    else:
        image_patch[ half_size[0] - _bias_start[0]: half_size[0] +_bias_end[0], \
                half_size[1] - _bias_start[1]: half_size[1] +_bias_end[1], \
                half_size[2] - _bias_start[2]: half_size[2] +_bias_end[2] ] = \
                ori_vol[ referece_ctr_idx[0] - _bias_start[0]: referece_ctr_idx[0] +_bias_end[0], \
                referece_ctr_idx[1] - _bias_start[1]: referece_ctr_idx[1] +_bias_end[1], \
                referece_ctr_idx[2] - _bias_start[2]: referece_ctr_idx[2] +_bias_end[2] ]

        image_patch = image_patch[ 0: crop_size[0], 0: crop_size[1], 0: crop_size[2] ]
    return image_patch

   
    
def copy_spacing_ori(src, dst):
    dst.SetSpacing(src.GetSpacing())
    dst.SetOrigin(src.GetOrigin())
    dst.SetDirection(src.GetDirection())
    return dst

# %%
imgs
# Out:
# ['/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_0.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_1.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_10.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_11.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_12.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_13.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_14.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_15.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_16.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_17.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_18.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_19.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_2.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_20.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_21.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_22.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_23.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_24.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_25.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_26.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_27.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_28.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_29.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_3.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_30.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_31.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_32.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_33.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_34.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_35.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_36.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_37.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_38.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_39.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_4.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_40.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_41.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_42.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_43.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_44.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_45.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_46.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_47.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_48.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_49.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_5.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_50.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_51.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_52.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_53.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_54.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_55.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_56.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_57.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_58.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_59.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_6.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_60.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_61.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_62.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_63.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_64.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_65.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_66.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_67.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_68.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_69.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_7.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_70.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_71.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_72.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_73.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_74.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_75.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_76.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_77.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_78.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_79.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_8.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_80.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_81.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_82.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/image_9.nii.gz']

# %%
segs
# Out:
# ['/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_0.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_1.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_10.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_11.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_12.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_13.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_14.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_15.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_16.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_17.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_18.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_19.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_2.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_20.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_21.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_22.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_23.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_24.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_25.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_26.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_27.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_28.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_29.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_3.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_30.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_31.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_32.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_33.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_34.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_35.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_36.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_37.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_38.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_39.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_4.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_40.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_41.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_42.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_43.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_44.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_45.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_46.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_47.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_48.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_49.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_5.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_50.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_51.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_52.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_53.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_54.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_55.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_56.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_57.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_58.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_59.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_6.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_60.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_61.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_62.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_63.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_64.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_65.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_66.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_67.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_68.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_69.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_7.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_70.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_71.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_72.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_73.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_74.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_75.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_76.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_77.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_78.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_79.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_8.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_80.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_81.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_82.nii.gz',
#  '/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/tmp_normalized/label_9.nii.gz']

# %%
import copy
OUT_FOLDER = "/content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized"
scan_dir = OUT_FOLDER
os.makedirs(scan_dir, exist_ok = True)
BD_BIAS = 32 # cut irrelavent empty boundary to make roi stands out

SPA_FAC = (512 - 2 * BD_BIAS) / 256 # spacing factor

for img_fid, seg_fid, pid in zip(imgs, segs, pids):

    lb_n = nio.read_nii_bysitk(seg_fid)

    img_obj = sitk.ReadImage( img_fid )
    seg_obj = sitk.ReadImage( seg_fid )

    ## image
    array = sitk.GetArrayFromImage(img_obj)
    # cropping
    array = array[:, BD_BIAS: -BD_BIAS, BD_BIAS: -BD_BIAS]
    cropped_img_o = sitk.GetImageFromArray(array)
    cropped_img_o = copy_spacing_ori(img_obj, cropped_img_o)

    # resampling
    img_spa_ori = img_obj.GetSpacing()
    res_img_o = resample_by_res(cropped_img_o, [img_spa_ori[0] * SPA_FAC, img_spa_ori[1] * SPA_FAC, img_spa_ori[-1]], interpolator = sitk.sitkLinear,
                                    logging = True)

    ## label
    lb_arr = sitk.GetArrayFromImage(seg_obj)
    
    # cropping
    lb_arr = lb_arr[:,BD_BIAS: -BD_BIAS, BD_BIAS: -BD_BIAS]
    cropped_lb_o = sitk.GetImageFromArray(lb_arr)
    cropped_lb_o = copy_spacing_ori(seg_obj, cropped_lb_o)

    lb_spa_ori = seg_obj.GetSpacing()

    # resampling
    res_lb_o = resample_lb_by_res(cropped_lb_o,  [lb_spa_ori[0] * SPA_FAC, lb_spa_ori[1] * SPA_FAC, lb_spa_ori[-1] ], interpolator = sitk.sitkLinear,
                                  ref_img = res_img_o, logging = True)

    
    out_img_fid = os.path.join( scan_dir, f'image_{pid}.nii.gz' )
    out_lb_fid  = os.path.join( scan_dir, f'label_{pid}.nii.gz' ) 
    
    # then save
    sitk.WriteImage(res_img_o, out_img_fid, True) 
    sitk.WriteImage(res_lb_o, out_lb_fid, True) 
    print("{} has been saved".format(out_img_fid))
    print("{} has been saved".format(out_lb_fid))
# Out:
# Spacing: (1.5625, 1.5625, 7.0) -> [2.734375, 2.734375, 7.0]
# Size (128, 92, 12) -> [73.14285714 52.57142857 12.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 7.0) -> [2.734375, 2.734375, 7.0]
# Size (128, 92, 12) -> [73.14285714 52.57142857 12.        ]
# Spacing: (1.5625, 1.5625, 7.0) -> [2.734375, 2.734375, 7.0]
# Size (128, 92, 12) -> [73.14285714 52.57142857 12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_0.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_0.nii.gz has been saved
# Spacing: (1.484375, 1.484375, 10.0) -> [2.59765625, 2.59765625, 10.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# Label values: [0 1]
# Spacing: (1.484375, 1.484375, 10.0) -> [2.59765625, 2.59765625, 10.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# Spacing: (1.484375, 1.484375, 10.0) -> [2.59765625, 2.59765625, 10.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_1.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_1.nii.gz has been saved
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 136, 12) -> [109.71428571  77.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 136, 12) -> [109.71428571  77.71428571  12.        ]
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 136, 12) -> [109.71428571  77.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_10.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_10.nii.gz has been saved
# Spacing: (1.7970000505447388, 1.7970000505447388, 8.0) -> [3.144750088453293, 3.144750088453293, 8.0]
# Size (192, 192, 15) -> [109.71428571 109.71428571  15.        ]
# Label values: [0 1]
# Spacing: (1.7970000505447388, 1.7970000505447388, 8.0) -> [3.144750088453293, 3.144750088453293, 8.0]
# Size (192, 192, 15) -> [109.71428571 109.71428571  15.        ]
# Spacing: (1.7970000505447388, 1.7970000505447388, 8.0) -> [3.144750088453293, 3.144750088453293, 8.0]
# Size (192, 192, 15) -> [109.71428571 109.71428571  15.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_11.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_11.nii.gz has been saved
# Spacing: (1.3671799898147583, 1.367169976234436, 8.0) -> [2.392564982175827, 2.392547458410263, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.3671799898147583, 1.367169976234436, 8.0) -> [2.392564982175827, 2.392547458410263, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Spacing: (1.3671799898147583, 1.367169976234436, 8.0) -> [2.392564982175827, 2.392547458410263, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_12.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_12.nii.gz has been saved
# Spacing: (1.445330023765564, 1.4453200101852417, 8.0) -> [2.529327541589737, 2.529310017824173, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.445330023765564, 1.4453200101852417, 8.0) -> [2.529327541589737, 2.529310017824173, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Spacing: (1.445330023765564, 1.4453200101852417, 8.0) -> [2.529327541589737, 2.529310017824173, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_13.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_13.nii.gz has been saved
# Spacing: (1.3671599626541138, 1.367169976234436, 8.0) -> [2.392529934644699, 2.392547458410263, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# Label values: [0 1]
# Spacing: (1.3671599626541138, 1.367169976234436, 8.0) -> [2.392529934644699, 2.392547458410263, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# Spacing: (1.3671599626541138, 1.367169976234436, 8.0) -> [2.392529934644699, 2.392547458410263, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_14.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_14.nii.gz has been saved
# Spacing: (1.3671900033950806, 1.3671900033950806, 8.0) -> [2.392582505941391, 2.392582505941391, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.3671900033950806, 1.3671900033950806, 8.0) -> [2.392582505941391, 2.392582505941391, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Spacing: (1.3671900033950806, 1.3671900033950806, 8.0) -> [2.392582505941391, 2.392582505941391, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_15.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_15.nii.gz has been saved
# Spacing: (1.2911938428878784, 1.2911938428878784, 8.0) -> [2.2595892250537872, 2.2595892250537872, 8.0]
# Size (224, 224, 14) -> [128. 128.  14.]
# Label values: [0 1]
# Spacing: (1.2911938428878784, 1.2911938428878784, 8.0) -> [2.2595892250537872, 2.2595892250537872, 8.0]
# Size (224, 224, 14) -> [128. 128.  14.]
# Spacing: (1.2911938428878784, 1.2911938428878784, 8.0) -> [2.2595892250537872, 2.2595892250537872, 8.0]
# Size (224, 224, 14) -> [128. 128.  14.]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_16.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_16.nii.gz has been saved
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 14) -> [256. 256.  14.]
# Label values: [0 1]
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 14) -> [256. 256.  14.]
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 14) -> [256. 256.  14.]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_17.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_17.nii.gz has been saved
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 15) -> [256. 256.  15.]
# Label values: [0 1]
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 15) -> [256. 256.  15.]
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 15) -> [256. 256.  15.]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_18.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_18.nii.gz has been saved
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 13) -> [256. 256.  13.]
# Label values: [0 1]
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 13) -> [256. 256.  13.]
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 13) -> [256. 256.  13.]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_19.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_19.nii.gz has been saved
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 122, 8) -> [73.14285714 69.71428571  8.        ]
# Label values: [0 1]
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 122, 8) -> [73.14285714 69.71428571  8.        ]
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 122, 8) -> [73.14285714 69.71428571  8.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_2.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_2.nii.gz has been saved
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 17) -> [256. 256.  17.]
# Label values: [0 1]
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 17) -> [256. 256.  17.]
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 17) -> [256. 256.  17.]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_20.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_20.nii.gz has been saved
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 15) -> [256. 256.  15.]
# Label values: [0 1]
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 15) -> [256. 256.  15.]
# Spacing: (0.7031000256538391, 0.7031000256538391, 8.0) -> [1.2304250448942184, 1.2304250448942184, 8.0]
# Size (448, 448, 15) -> [256. 256.  15.]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_21.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_21.nii.gz has been saved
# Spacing: (1.3280999660491943, 1.3280999660491943, 6.0) -> [2.32417494058609, 2.32417494058609, 6.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.3280999660491943, 1.3280999660491943, 6.0) -> [2.32417494058609, 2.32417494058609, 6.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Spacing: (1.3280999660491943, 1.3280999660491943, 6.0) -> [2.32417494058609, 2.32417494058609, 6.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_22.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_22.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 6.0) -> [2.734375, 2.734375, 6.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 6.0) -> [2.734375, 2.734375, 6.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Spacing: (1.5625, 1.5625, 6.0) -> [2.734375, 2.734375, 6.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_23.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_23.nii.gz has been saved
# Spacing: (1.25, 1.25, 6.0) -> [2.1875, 2.1875, 6.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Label values: [0 1]
# Spacing: (1.25, 1.25, 6.0) -> [2.1875, 2.1875, 6.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Spacing: (1.25, 1.25, 6.0) -> [2.1875, 2.1875, 6.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_24.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_24.nii.gz has been saved
# Spacing: (1.2891000509262085, 1.2891000509262085, 6.0) -> [2.255925089120865, 2.255925089120865, 6.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Label values: [0 1]
# Spacing: (1.2891000509262085, 1.2891000509262085, 6.0) -> [2.255925089120865, 2.255925089120865, 6.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Spacing: (1.2891000509262085, 1.2891000509262085, 6.0) -> [2.255925089120865, 2.255925089120865, 6.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_25.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_25.nii.gz has been saved
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_26.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_26.nii.gz has been saved
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Label values: [0 1]
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_27.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_27.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_28.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_28.nii.gz has been saved
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Label values: [0 1]
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_29.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_29.nii.gz has been saved
# Spacing: (1.953125, 1.953125, 8.0) -> [3.41796875, 3.41796875, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Label values: [0 1]
# Spacing: (1.953125, 1.953125, 8.0) -> [3.41796875, 3.41796875, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Spacing: (1.953125, 1.953125, 8.0) -> [3.41796875, 3.41796875, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_3.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_3.nii.gz has been saved
# Spacing: (1.4452999830245972, 1.4452999830245972, 8.0) -> [2.529274970293045, 2.529274970293045, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Label values: [0 1]
# Spacing: (1.4452999830245972, 1.4452999830245972, 8.0) -> [2.529274970293045, 2.529274970293045, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Spacing: (1.4452999830245972, 1.4452999830245972, 8.0) -> [2.529274970293045, 2.529274970293045, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_30.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_30.nii.gz has been saved
# Spacing: (1.3672000169754028, 1.3672000169754028, 8.0) -> [2.392600029706955, 2.392600029706955, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Label values: [0 1]
# Spacing: (1.3672000169754028, 1.3672000169754028, 8.0) -> [2.392600029706955, 2.392600029706955, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Spacing: (1.3672000169754028, 1.3672000169754028, 8.0) -> [2.392600029706955, 2.392600029706955, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_31.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_31.nii.gz has been saved
# Spacing: (1.3672000169754028, 1.3672000169754028, 8.0) -> [2.392600029706955, 2.392600029706955, 8.0]
# Size (192, 192, 15) -> [109.71428571 109.71428571  15.        ]
# Label values: [0 1]
# Spacing: (1.3672000169754028, 1.3672000169754028, 8.0) -> [2.392600029706955, 2.392600029706955, 8.0]
# Size (192, 192, 15) -> [109.71428571 109.71428571  15.        ]
# Spacing: (1.3672000169754028, 1.3672000169754028, 8.0) -> [2.392600029706955, 2.392600029706955, 8.0]
# Size (192, 192, 15) -> [109.71428571 109.71428571  15.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_32.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_32.nii.gz has been saved
# Spacing: (1.3672000169754028, 1.3672000169754028, 8.0) -> [2.392600029706955, 2.392600029706955, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.3672000169754028, 1.3672000169754028, 8.0) -> [2.392600029706955, 2.392600029706955, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Spacing: (1.3672000169754028, 1.3672000169754028, 8.0) -> [2.392600029706955, 2.392600029706955, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_33.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_33.nii.gz has been saved
# Spacing: (1.2890625, 1.2890625, 8.0) -> [2.255859375, 2.255859375, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.2890625, 1.2890625, 8.0) -> [2.255859375, 2.255859375, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Spacing: (1.2890625, 1.2890625, 8.0) -> [2.255859375, 2.255859375, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_34.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_34.nii.gz has been saved
# Spacing: (1.46484375, 1.46484375, 6.0) -> [2.5634765625, 2.5634765625, 6.0]
# Size (192, 128, 13) -> [109.71428571  73.14285714  13.        ]
# Label values: [0 1]
# Spacing: (1.46484375, 1.46484375, 6.0) -> [2.5634765625, 2.5634765625, 6.0]
# Size (192, 128, 13) -> [109.71428571  73.14285714  13.        ]
# Spacing: (1.46484375, 1.46484375, 6.0) -> [2.5634765625, 2.5634765625, 6.0]
# Size (192, 128, 13) -> [109.71428571  73.14285714  13.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_35.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_35.nii.gz has been saved
# Spacing: (1.5234375, 1.5234375, 6.0) -> [2.666015625, 2.666015625, 6.0]
# Size (192, 128, 13) -> [109.71428571  73.14285714  13.        ]
# Label values: [0 1]
# Spacing: (1.5234375, 1.5234375, 6.0) -> [2.666015625, 2.666015625, 6.0]
# Size (192, 128, 13) -> [109.71428571  73.14285714  13.        ]
# Spacing: (1.5234375, 1.5234375, 6.0) -> [2.666015625, 2.666015625, 6.0]
# Size (192, 128, 13) -> [109.71428571  73.14285714  13.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_36.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_36.nii.gz has been saved
# Spacing: (1.484375, 1.484375, 6.0) -> [2.59765625, 2.59765625, 6.0]
# Size (192, 136, 11) -> [109.71428571  77.71428571  11.        ]
# Label values: [0 1]
# Spacing: (1.484375, 1.484375, 6.0) -> [2.59765625, 2.59765625, 6.0]
# Size (192, 136, 11) -> [109.71428571  77.71428571  11.        ]
# Spacing: (1.484375, 1.484375, 6.0) -> [2.59765625, 2.59765625, 6.0]
# Size (192, 136, 11) -> [109.71428571  77.71428571  11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_37.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_37.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 16) -> [109.71428571 109.71428571  16.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 16) -> [109.71428571 109.71428571  16.        ]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 16) -> [109.71428571 109.71428571  16.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_38.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_38.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_39.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_39.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_4.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_4.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_40.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_40.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 16) -> [109.71428571 109.71428571  16.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 16) -> [109.71428571 109.71428571  16.        ]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 16) -> [109.71428571 109.71428571  16.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_41.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_41.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_42.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_42.nii.gz has been saved
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# Label values: [0 1]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_43.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_43.nii.gz has been saved
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# Label values: [0 1]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_44.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_44.nii.gz has been saved
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# Label values: [0 1]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 11) -> [109.71428571 109.71428571  11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_45.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_45.nii.gz has been saved
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Label values: [0 1]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_46.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_46.nii.gz has been saved
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Label values: [0 1]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_47.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_47.nii.gz has been saved
# Spacing: (1.484375, 1.484375, 8.0) -> [2.59765625, 2.59765625, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.484375, 1.484375, 8.0) -> [2.59765625, 2.59765625, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Spacing: (1.484375, 1.484375, 8.0) -> [2.59765625, 2.59765625, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_48.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_48.nii.gz has been saved
# Spacing: (1.4062999486923218, 1.4062999486923218, 8.0) -> [2.461024910211563, 2.461024910211563, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Label values: [0 1]
# Spacing: (1.4062999486923218, 1.4062999486923218, 8.0) -> [2.461024910211563, 2.461024910211563, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Spacing: (1.4062999486923218, 1.4062999486923218, 8.0) -> [2.461024910211563, 2.461024910211563, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_49.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_49.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (224, 224, 12) -> [128. 128.  12.]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (224, 224, 12) -> [128. 128.  12.]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (224, 224, 12) -> [128. 128.  12.]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_5.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_5.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_50.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_50.nii.gz has been saved
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 10) -> [73.14285714 73.14285714 10.        ]
# Label values: [0 1]
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 10) -> [73.14285714 73.14285714 10.        ]
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 10) -> [73.14285714 73.14285714 10.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_51.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_51.nii.gz has been saved
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 152, 9) -> [109.71428571  86.85714286   9.        ]
# Label values: [0 1]
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 152, 9) -> [109.71428571  86.85714286   9.        ]
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 152, 9) -> [109.71428571  86.85714286   9.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_52.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_52.nii.gz has been saved
# Spacing: (1.7970000505447388, 1.7970000505447388, 8.0) -> [3.144750088453293, 3.144750088453293, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Label values: [0 1]
# Spacing: (1.7970000505447388, 1.7970000505447388, 8.0) -> [3.144750088453293, 3.144750088453293, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# Spacing: (1.7970000505447388, 1.7970000505447388, 8.0) -> [3.144750088453293, 3.144750088453293, 8.0]
# Size (192, 192, 13) -> [109.71428571 109.71428571  13.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_53.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_53.nii.gz has been saved
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (256, 256, 14) -> [146.28571429 146.28571429  14.        ]
# Label values: [0 1]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (256, 256, 14) -> [146.28571429 146.28571429  14.        ]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (256, 256, 14) -> [146.28571429 146.28571429  14.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_54.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_54.nii.gz has been saved
# Spacing: (1.4453125, 1.4453125, 8.0) -> [2.529296875, 2.529296875, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.4453125, 1.4453125, 8.0) -> [2.529296875, 2.529296875, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Spacing: (1.4453125, 1.4453125, 8.0) -> [2.529296875, 2.529296875, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_55.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_55.nii.gz has been saved
# Spacing: (1.7708333730697632, 1.7708333730697632, 6.0) -> [3.0989584028720856, 3.0989584028720856, 6.0]
# Size (128, 128, 12) -> [73.14285714 73.14285714 12.        ]
# Label values: [0 1]
# Spacing: (1.7708333730697632, 1.7708333730697632, 6.0) -> [3.0989584028720856, 3.0989584028720856, 6.0]
# Size (128, 128, 12) -> [73.14285714 73.14285714 12.        ]
# Spacing: (1.7708333730697632, 1.7708333730697632, 6.0) -> [3.0989584028720856, 3.0989584028720856, 6.0]
# Size (128, 128, 12) -> [73.14285714 73.14285714 12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_56.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_56.nii.gz has been saved
# Spacing: (1.484375, 1.484375, 8.0) -> [2.59765625, 2.59765625, 8.0]
# Size (192, 144, 9) -> [109.71428571  82.28571429   9.        ]
# Label values: [0 1]
# Spacing: (1.484375, 1.484375, 8.0) -> [2.59765625, 2.59765625, 8.0]
# Size (192, 144, 9) -> [109.71428571  82.28571429   9.        ]
# Spacing: (1.484375, 1.484375, 8.0) -> [2.59765625, 2.59765625, 8.0]
# Size (192, 144, 9) -> [109.71428571  82.28571429   9.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_57.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_57.nii.gz has been saved
# Spacing: (1.40625, 1.40625, 6.0) -> [2.4609375, 2.4609375, 6.0]
# Size (192, 144, 11) -> [109.71428571  82.28571429  11.        ]
# Label values: [0 1]
# Spacing: (1.40625, 1.40625, 6.0) -> [2.4609375, 2.4609375, 6.0]
# Size (192, 144, 11) -> [109.71428571  82.28571429  11.        ]
# Spacing: (1.40625, 1.40625, 6.0) -> [2.4609375, 2.4609375, 6.0]
# Size (192, 144, 11) -> [109.71428571  82.28571429  11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_58.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_58.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 10.0) -> [2.734375, 2.734375, 10.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 10.0) -> [2.734375, 2.734375, 10.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Spacing: (1.5625, 1.5625, 10.0) -> [2.734375, 2.734375, 10.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_59.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_59.nii.gz has been saved
# Spacing: (1.6666666269302368, 1.6666666269302368, 8.0) -> [2.9166665971279144, 2.9166665971279144, 8.0]
# Size (176, 176, 12) -> [100.57142857 100.57142857  12.        ]
# Label values: [0 1]
# Spacing: (1.6666666269302368, 1.6666666269302368, 8.0) -> [2.9166665971279144, 2.9166665971279144, 8.0]
# Size (176, 176, 12) -> [100.57142857 100.57142857  12.        ]
# Spacing: (1.6666666269302368, 1.6666666269302368, 8.0) -> [2.9166665971279144, 2.9166665971279144, 8.0]
# Size (176, 176, 12) -> [100.57142857 100.57142857  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_6.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_6.nii.gz has been saved
# Spacing: (1.4322916269302368, 1.4322916269302368, 7.0) -> [2.5065103471279144, 2.5065103471279144, 7.0]
# Size (128, 128, 15) -> [73.14285714 73.14285714 15.        ]
# Label values: [0 1]
# Spacing: (1.4322916269302368, 1.4322916269302368, 7.0) -> [2.5065103471279144, 2.5065103471279144, 7.0]
# Size (128, 128, 15) -> [73.14285714 73.14285714 15.        ]
# Spacing: (1.4322916269302368, 1.4322916269302368, 7.0) -> [2.5065103471279144, 2.5065103471279144, 7.0]
# Size (128, 128, 15) -> [73.14285714 73.14285714 15.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_60.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_60.nii.gz has been saved
# Spacing: (1.875, 1.875, 6.0) -> [3.28125, 3.28125, 6.0]
# Size (128, 92, 8) -> [73.14285714 52.57142857  8.        ]
# Label values: [0 1]
# Spacing: (1.875, 1.875, 6.0) -> [3.28125, 3.28125, 6.0]
# Size (128, 92, 8) -> [73.14285714 52.57142857  8.        ]
# Spacing: (1.875, 1.875, 6.0) -> [3.28125, 3.28125, 6.0]
# Size (128, 92, 8) -> [73.14285714 52.57142857  8.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_61.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_61.nii.gz has been saved
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 128, 9) -> [73.14285714 73.14285714  9.        ]
# Label values: [0 1]
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 128, 9) -> [73.14285714 73.14285714  9.        ]
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 128, 9) -> [73.14285714 73.14285714  9.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_62.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_62.nii.gz has been saved
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 160, 11) -> [109.71428571  91.42857143  11.        ]
# Label values: [0 1]
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 160, 11) -> [109.71428571  91.42857143  11.        ]
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 160, 11) -> [109.71428571  91.42857143  11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_63.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_63.nii.gz has been saved
# Spacing: (1.875, 1.875, 6.0) -> [3.28125, 3.28125, 6.0]
# Size (128, 92, 8) -> [73.14285714 52.57142857  8.        ]
# Label values: [0 1]
# Spacing: (1.875, 1.875, 6.0) -> [3.28125, 3.28125, 6.0]
# Size (128, 92, 8) -> [73.14285714 52.57142857  8.        ]
# Spacing: (1.875, 1.875, 6.0) -> [3.28125, 3.28125, 6.0]
# Size (128, 92, 8) -> [73.14285714 52.57142857  8.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_64.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_64.nii.gz has been saved
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 10) -> [73.14285714 73.14285714 10.        ]
# Label values: [0 1]
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 10) -> [73.14285714 73.14285714 10.        ]
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 10) -> [73.14285714 73.14285714 10.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_65.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_65.nii.gz has been saved
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 98, 11) -> [73.14285714 56.         11.        ]
# Label values: [0 1]
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 98, 11) -> [73.14285714 56.         11.        ]
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 98, 11) -> [73.14285714 56.         11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_66.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_66.nii.gz has been saved
# Spacing: (2.0833332538604736, 2.0833332538604736, 6.0) -> [3.645833194255829, 3.645833194255829, 6.0]
# Size (128, 128, 10) -> [73.14285714 73.14285714 10.        ]
# Label values: [0 1]
# Spacing: (2.0833332538604736, 2.0833332538604736, 6.0) -> [3.645833194255829, 3.645833194255829, 6.0]
# Size (128, 128, 10) -> [73.14285714 73.14285714 10.        ]
# Spacing: (2.0833332538604736, 2.0833332538604736, 6.0) -> [3.645833194255829, 3.645833194255829, 6.0]
# Size (128, 128, 10) -> [73.14285714 73.14285714 10.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_67.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_67.nii.gz has been saved
# Spacing: (1.7970000505447388, 1.7970000505447388, 8.0) -> [3.144750088453293, 3.144750088453293, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Label values: [0 1]
# Spacing: (1.7970000505447388, 1.7970000505447388, 8.0) -> [3.144750088453293, 3.144750088453293, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Spacing: (1.7970000505447388, 1.7970000505447388, 8.0) -> [3.144750088453293, 3.144750088453293, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_68.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_68.nii.gz has been saved
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Label values: [0 1]
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# Spacing: (1.3671875, 1.3671875, 8.0) -> [2.392578125, 2.392578125, 8.0]
# Size (192, 192, 14) -> [109.71428571 109.71428571  14.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_69.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_69.nii.gz has been saved
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (256, 256, 13) -> [146.28571429 146.28571429  13.        ]
# Label values: [0 1]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (256, 256, 13) -> [146.28571429 146.28571429  13.        ]
# Spacing: (1.5625, 1.5625, 8.0) -> [2.734375, 2.734375, 8.0]
# Size (256, 256, 13) -> [146.28571429 146.28571429  13.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_7.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_7.nii.gz has been saved
# Spacing: (1.2890625, 1.2890625, 8.0) -> [2.255859375, 2.255859375, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Label values: [0 1]
# Spacing: (1.2890625, 1.2890625, 8.0) -> [2.255859375, 2.255859375, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Spacing: (1.2890625, 1.2890625, 8.0) -> [2.255859375, 2.255859375, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_70.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_70.nii.gz has been saved
# Spacing: (1.1805555820465088, 1.1805555820465088, 8.0) -> [2.0659722685813904, 2.0659722685813904, 8.0]
# Size (224, 224, 12) -> [128. 128.  12.]
# Label values: [0 1]
# Spacing: (1.1805555820465088, 1.1805555820465088, 8.0) -> [2.0659722685813904, 2.0659722685813904, 8.0]
# Size (224, 224, 12) -> [128. 128.  12.]
# Spacing: (1.1805555820465088, 1.1805555820465088, 8.0) -> [2.0659722685813904, 2.0659722685813904, 8.0]
# Size (224, 224, 12) -> [128. 128.  12.]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_71.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_71.nii.gz has been saved
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Label values: [0 1]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_72.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_72.nii.gz has been saved
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Label values: [0 1]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 10) -> [109.71428571 109.71428571  10.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_73.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_73.nii.gz has been saved
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 16) -> [109.71428571 109.71428571  16.        ]
# Label values: [0 1]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 16) -> [109.71428571 109.71428571  16.        ]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 16) -> [109.71428571 109.71428571  16.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_74.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_74.nii.gz has been saved
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Label values: [0 1]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# Spacing: (1.25, 1.25, 8.0) -> [2.1875, 2.1875, 8.0]
# Size (192, 192, 12) -> [109.71428571 109.71428571  12.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_75.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_75.nii.gz has been saved
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 11) -> [73.14285714 73.14285714 11.        ]
# Label values: [0 1]
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 11) -> [73.14285714 73.14285714 11.        ]
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 11) -> [73.14285714 73.14285714 11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_76.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_76.nii.gz has been saved
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 110, 11) -> [73.14285714 62.85714286 11.        ]
# Label values: [0 1]
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 110, 11) -> [73.14285714 62.85714286 11.        ]
# Spacing: (1.9791666269302368, 1.9791666269302368, 6.0) -> [3.4635415971279144, 3.4635415971279144, 6.0]
# Size (128, 110, 11) -> [73.14285714 62.85714286 11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_77.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_77.nii.gz has been saved
# Spacing: (1.71875, 1.71875, 6.0) -> [3.0078125, 3.0078125, 6.0]
# Size (128, 110, 11) -> [73.14285714 62.85714286 11.        ]
# Label values: [0 1]
# Spacing: (1.71875, 1.71875, 6.0) -> [3.0078125, 3.0078125, 6.0]
# Size (128, 110, 11) -> [73.14285714 62.85714286 11.        ]
# Spacing: (1.71875, 1.71875, 6.0) -> [3.0078125, 3.0078125, 6.0]
# Size (128, 110, 11) -> [73.14285714 62.85714286 11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_78.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_78.nii.gz has been saved
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 11) -> [73.14285714 73.14285714 11.        ]
# Label values: [0 1]
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 11) -> [73.14285714 73.14285714 11.        ]
# Spacing: (1.8229166269302368, 1.8229166269302368, 6.0) -> [3.1901040971279144, 3.1901040971279144, 6.0]
# Size (128, 128, 11) -> [73.14285714 73.14285714 11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_79.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_79.nii.gz has been saved
# Spacing: (1.7708333730697632, 1.7708333730697632, 6.0) -> [3.0989584028720856, 3.0989584028720856, 6.0]
# Size (128, 92, 15) -> [73.14285714 52.57142857 15.        ]
# Label values: [0 1]
# Spacing: (1.7708333730697632, 1.7708333730697632, 6.0) -> [3.0989584028720856, 3.0989584028720856, 6.0]
# Size (128, 92, 15) -> [73.14285714 52.57142857 15.        ]
# Spacing: (1.7708333730697632, 1.7708333730697632, 6.0) -> [3.0989584028720856, 3.0989584028720856, 6.0]
# Size (128, 92, 15) -> [73.14285714 52.57142857 15.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_8.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_8.nii.gz has been saved
# Spacing: (1.7708333730697632, 1.7708333730697632, 6.0) -> [3.0989584028720856, 3.0989584028720856, 6.0]
# Size (128, 92, 11) -> [73.14285714 52.57142857 11.        ]
# Label values: [0 1]
# Spacing: (1.7708333730697632, 1.7708333730697632, 6.0) -> [3.0989584028720856, 3.0989584028720856, 6.0]
# Size (128, 92, 11) -> [73.14285714 52.57142857 11.        ]
# Spacing: (1.7708333730697632, 1.7708333730697632, 6.0) -> [3.0989584028720856, 3.0989584028720856, 6.0]
# Size (128, 92, 11) -> [73.14285714 52.57142857 11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_80.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_80.nii.gz has been saved
# Spacing: (1.875, 1.875, 6.0) -> [3.28125, 3.28125, 6.0]
# Size (128, 98, 11) -> [73.14285714 56.         11.        ]
# Label values: [0 1]
# Spacing: (1.875, 1.875, 6.0) -> [3.28125, 3.28125, 6.0]
# Size (128, 98, 11) -> [73.14285714 56.         11.        ]
# Spacing: (1.875, 1.875, 6.0) -> [3.28125, 3.28125, 6.0]
# Size (128, 98, 11) -> [73.14285714 56.         11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_81.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_81.nii.gz has been saved
# Spacing: (1.40625, 1.40625, 6.0) -> [2.4609375, 2.4609375, 6.0]
# Size (192, 152, 11) -> [109.71428571  86.85714286  11.        ]
# Label values: [0 1]
# Spacing: (1.40625, 1.40625, 6.0) -> [2.4609375, 2.4609375, 6.0]
# Size (192, 152, 11) -> [109.71428571  86.85714286  11.        ]
# Spacing: (1.40625, 1.40625, 6.0) -> [2.4609375, 2.4609375, 6.0]
# Size (192, 152, 11) -> [109.71428571  86.85714286  11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_82.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_82.nii.gz has been saved
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 136, 11) -> [109.71428571  77.71428571  11.        ]
# Label values: [0 1]
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 136, 11) -> [109.71428571  77.71428571  11.        ]
# Spacing: (1.328125, 1.328125, 6.0) -> [2.32421875, 2.32421875, 6.0]
# Size (192, 136, 11) -> [109.71428571  77.71428571  11.        ]
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/image_9.nii.gz has been saved
# /content/gdrive/MyDrive/One-Shot/Few-Shot-Medical-Segmentation/data/SABS/sabs_CT_normalized/label_9.nii.gz has been saved
